# %% [markdown]
# # Data Analysis on Student Performance Analysis
#
# ## Notebook 2 - Exploratory Data Analysis (EDA)

# %% [markdown]
# **Author:** Junhyuk Lee
#
# **Date:** April 6, 2026

# %% [markdown]
# ## Contents

# %% [markdown]
# - Abstract
# - Imports
# - Exploratory Data Analysis

# %% [markdown]
# ---

# %% [markdown]
# ## Abstract

# %% [markdown]
# In this notebook, we will perform Exploratory Data Analysis (EDA) to uncover patterns, detect anomalies, and generate insights from the Students Performance dataset, which has been processed and cleaned in `01_preprocessing.ipynb`.
#
# The notebook includes univariate and multivariate analysis using statistical summaries and visualizations. The goal is to understand the data better in preparation for our data analysis.

# %% [markdown]
# ---

# %% [markdown]
# ## Imports

# %% [markdown]
# In addition to `numpy` and `pandas`, we will also import data visualization libraries such as `matplotlib` and `seaborn`.

# %%
import numpy as np
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Suppress warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
# Reading in the dataset
students = pd.read_csv("../data/processed/students_cleaned.csv")

# %% [markdown]
# ---

# %% [markdown]
# ## Exploratory Data Analysis - Univariate Analysis

# %% [markdown]
# Let's explore our data set to get a better understanding of our dataset, and see if we can uncover any hidden patterns.

# %% [markdown]
# We'll start by using the `df.describe()` method to generate a statistical summary of our dataset.

# %%
students.describe().round(3)
# Out:
#              age  university_year        GPA  study_hours_per_day  \
# count  10000.000        10000.000  10000.000            10000.000
# mean      22.953            2.510      3.618                3.509
# std        3.159            1.124      0.395                1.474
# min       18.000            1.000      1.920                0.500
# 25%       20.000            1.750      3.360                2.500
# 50%       23.000            3.000      3.710                3.500
# 75%       26.000            4.000      4.000                4.500
# max       28.000            4.000      4.000                9.400
#
#        class_attendance_percent  sleep_hours  screen_time_hours  \
# count                 10000.000    10000.000          10000.000
# mean                     90.488        7.014              5.790
# std                       9.953        1.192              1.882
# min                      44.000        3.500              1.000
# ...
